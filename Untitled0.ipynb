# %% [markdown]
# <a href="https://colab.research.google.com/github/Diannefloress/Laboratorio_1022/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #creacion de data set

# %%
import pandas as pd
data=[[1,"jos",19],[2,"david",22],[3,"cris",20],[4,"ivana",23]]
df = pd.DataFrame(data, columns=["id","name","age"])
print(df)
# Out:
#    id   name  age
# 0   1    jos   19
# 1   2  david   22
# 2   3   cris   20
# 3   4  ivana   23

# %% [markdown]
# # Crear un DataFrame a partir de un csv

# %%
import pandas as  pd
path="/content/sample_data/california_housing_test.csv"
df = pd.read_csv(path)
df.describe(include='all').round(1)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# count     3000.0    3000.0              3000.0       3000.0          3000.0
# mean      -119.6      35.6                28.8       2599.6           530.0
# std          2.0       2.1                12.6       2155.6           415.7
# min       -124.2      32.6                 1.0          6.0             2.0
# 25%       -121.8      33.9                18.0       1401.0           291.0
# 50%       -118.5      34.3                29.0       2106.0           437.0
# 75%       -118.0      37.7                37.0       3129.0           636.0
# max       -114.5      41.9                52.0      30450.0          5419.0
#
#        population  households  median_income  median_house_value
# count      3000.0      3000.0         3000.0              3000.0
# mean       1402.8       489.9            3.8            205846.3
# std        1030.5       365.4            1.9            113119.7
# ...

# %% [markdown]
# # montaje drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
